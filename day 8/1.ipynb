# %%
p = "aBc"
print(p.swapcase())
print(p)
# Out:
# AbC
# aBc

# %%
#replace
html_data =input("Give me a html input")
for ch in "<>/":
    html_data= html_data.replace(ch," ")
print(html_data)
# Out:
# pnoj

# %%
html_data = str(input("give me a input"))
if html_data.startswith("<") and html_data.endswith(">"):
    print("user is putting html")
else: 
    print("good night")
# Out:
# good night

# %%
input = input("Enter a string: ")
length = len(input)
print(f"The length of the string is: {length}")

# %%
String = input("Enter a string: ")
if String == String[::-1]:
    print(f"'{String}' is a palindrome")
else:
    print(f"'{String}' is not a palindrome")
# Out:
# 'aaa' is a palindrome

# %%
email = input("Enter an email: ")
domain = email.split("@")[1]
print(f"The domain is: {domain}")
# Out:
# The domain is: hjbjh.com

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
email = input("Enter an email: ")
mail, domain = email.split("@")
masked_mail = mail[0:3] + "*" * (len(mail) - 2)
masked_email = masked_mail + "@" + domain
print(f"Masked email: {masked_email}")
# Out:
# Masked email: bhg***@bhjbj

# %%
file_name = input("Enter file name: ")
first = file_name.split(".")[1]
print(f"extention name: {first}")
# Out:
# extention name: ghbj

# %%
url = input("Enter a URL: ")
if url.startswith("https://"):
    print("The URL is secured")
else:
    print("The URL is not secured")
# Out:
# The URL is not secured

# %%
a = [1,2,3]
print(id(a))
a.append(5)
print(a)
print(id(a))
# Out:
# 2398838031104
# [1, 2, 3, 5]
# 2398838031104

# %%
print(a)
a.clear()
print(a)
help(a.extend)
print(a)
# Out:
# [1, 2, 3, 5]
# []
# Help on built-in function extend:
#
# extend(iterable, /) method of builtins.list instance
#     Extend list by appending elements from the iterable.
#
# []

# %%
list_methods = sorted([name for name in dir(list) if not name.startswith("__")])
for method in list_methods:
    print(method)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
all_methods = sorted([name for name in dir(list) if callable(getattr(list, name, None)) and not name.startswith("__")])


if 'method' in globals() and method in all_methods:
    all_methods.remove(method)

for m in all_methods:
    print(m)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse

# %%
z=dir(list)
print(z)
if(z.startswith("__")):
    print()
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
site = ['mobile','car','tv']
site.remove('car')
print(site)
dona = [1,2,3,4,5,6,7,8]
count()

# %%
list1 = [1,2,3]
list1.reverse()
print(list1)
# Out:
# [3, 2, 1]

# %%
t = (1,2,3,4)
len(t)
# Out:
# 4

# %%
t = (130,324,0,2,0,33)
print(sum(t))
print(min(t))
print(max(t))
print(t[0:5])
print(t[-1])
# Out:
# 489
# 0
# 324
# (130, 324, 0, 2, 0)
# 33

# %%
a,b,c,d,e,f=t
print(a)
# Out:
# 130

# %%
student = {
    "name": "tom",
    "roll": 132,
    "reg": 12323486,
    "sem":6

}
print(student["name"])
# Out:
# tom

# %%
student = {
    "address": {"city": "Delhi", "pin": 110001}, 
    "name": "tom",
    "roll": 132,
    "reg": 12323486,
    "sem": 6
}
student["name"] = "priyank"
print(student["name"])
print(student)
# Out:
# priyank
# {'address': {'city': 'Delhi', 'pin': 110001}, 'name': 'priyank', 'roll': 132, 'reg': 12323486, 'sem': 6}

# %%
print(student.keys())
print(student.values())
# Out:
# dict_keys(['name', 'roll', 'reg', 'sem'])
# dict_values(['priyank', 132, 12323486, 6])

# %%
a=dir(set)
for m in a:
    print(m)
# Out:
# __and__
# __class__
# __class_getitem__
# __contains__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __iand__
# __init__
# __init_subclass__
# __ior__
# __isub__
# __iter__
# __ixor__
# __le__
# __len__
# __lt__
# __ne__
# __new__
# __or__
# __rand__
# __reduce__
# __reduce_ex__
# __repr__
# __ror__
# __rsub__
# __rxor__
# __setattr__
# __sizeof__
# __str__
# __sub__
# __subclasshook__
# __xor__
# add
# clear
# copy
# difference
# difference_update
# discard
# intersection
# intersection_update
# isdisjoint
# issubset
# issuperset
# pop
# remove
# symmetric_difference
# symmetric_difference_update
# union
# update

# %%
b={1,8,"b",78,"bjh"}
print(b)
print(type(b))
print(b.add(9))
print(b)
print()
# Out:
# {1, 'b', 8, 'bjh', 78}
# <class 'set'>
# None
# {1, 'b', 8, 9, 'bjh', 78}

# %%
a=[1,2,3,4]
b= set(a)
print(type(b))
# Out:
# <class 'set'>

# %%
a=dir(set)
b=set(a)
print(b)
# Out:
# {'__str__', 'update', '__or__', '__ge__', '__sub__', '__le__', '__ror__', '__rxor__', '__new__', '__setattr__', '__delattr__', 'difference', 'clear', '__iter__', 'copy', 'intersection', '__reduce__', '__dir__', 'intersection_update', '__xor__', '__ixor__', '__rand__', '__init_subclass__', '__class_getitem__', '__subclasshook__', 'issuperset', 'issubset', '__gt__', '__and__', 'symmetric_difference_update', '__doc__', '__rsub__', 'difference_update', 'add', '__ior__', '__ne__', '__eq__', '__reduce_ex__', '__repr__', '__getstate__', '__class__', 'symmetric_difference', '__format__', '__iand__', '__init__', '__contains__', '__sizeof__', '__isub__', '__lt__', 'pop', '__len__', '__hash__', 'discard', 'isdisjoint', 'remove', '__getattribute__', 'union'}

# %%
a="ab"
b="ab"
id(a)
# Out:
# 1388069048832
